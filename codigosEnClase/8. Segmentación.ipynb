# %%
Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.12.0.88)
Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.59.1)
Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.3)
Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import cv2
import matplotlib.pyplot as plt

# Cargar imagen en escala de grises
image = cv2.imread('/content/imagen_color.png', 0)

# Aplicar umbralización
ret, thresholded_image = cv2.threshold(image, 200, 255, cv2.THRESH_BINARY) # se puso 200 ya que mas bajo algunos elementos se pierden

# Mostrar imagen segmentada
# cv2.imshow('Segmentación por Umbralización', thresholded_image)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

plt.title('Segmentación por Umbralización')
plt.imshow(thresholded_image, cmap='gray')
plt.axis('off')  # Ocultar los ejes
plt.show()

# %%
# Aplicar umbralización adaptativa
#cv2.adaptiveThreshold(fuente, valormáximo, métodoadaptable, tipoUmbral, tamaño de bloque, constante)
'''
cv2.ADAPTIVE_THRESH_MEAN_C : Valor del umbral = (Media de los valores del área del vecindario – valor constante).
En otras palabras, es la media del tamaño del bloque × tamaño del bloque del vecindario de un punto
menos la constante.
cv2.ADAPTIVE_THRESH_GAUSSIAN_C : Valor de umbral = (suma ponderada gaussiana de los valores del vecindario –
valor constante). En otras palabras, es una suma ponderada del tamaño del bloque × tamaño del bloque del vecindario de un punto menos la constante.
-> thresholdType : el tipo de umbral que se aplicará.
-> blockSize : tamaño de un vecindario de píxeles que se utiliza para calcular un valor de umbral.
-> constant : un valor constante que se resta de la media o la suma ponderada de los píxeles del vecindario.
adaptive_threshold = cv2.adaptiveThreshold(image, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 11, 2)
'''
# Mostrar imagen segmentada
# cv2.imshow('Segmentación con Umbralización Adaptativa', adaptive_threshold)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

adaptive_threshold = cv2.adaptiveThreshold(image, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 11, 2)
plt.title('Segmentación por Umbralización Adaptativa Uno')
plt.imshow(adaptive_threshold, cmap='gray')
plt.axis('off')  # Ocultar los ejes
plt.show()

adaptive_threshold_2 = cv2.adaptiveThreshold(thresholded_image, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 11, 2)
plt.title('Segmentación por Umbralización Adaptativa Dos')
plt.imshow(adaptive_threshold_2, cmap='gray')
plt.axis('off')  # Ocultar los ejes
plt.show()

# %%
# Cargar imagen en escala de grises
image = cv2.imread('/content/imagen_color.png', 0)

# Aplicar el filtro de Canny para detección de bordes
edges = cv2.Canny(image, 100, 200)

# Mostrar resultados
# cv2.imshow('Bordes Detectados', edges)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

plt.title('Bordes Detectados')
plt.imshow(edges, cmap='gray')
plt.axis('off')  # Ocultar los ejes
plt.show()

# Aplicar el filtro de Canny para detección de bordes
edges_dos = cv2.Canny(thresholded_image, 100, 200)

# Mostrar resultados
# cv2.imshow('Bordes Detectados', edges)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

plt.title('Bordes Detectados')
plt.imshow(edges_dos, cmap='gray')
plt.axis('off')  # Ocultar los ejes
plt.show()

# %%
# Cargar imagen en escala de grises
image = cv2.imread('/content/imagen_color.png', 0)

# Aplicar umbralización
ret, thresholded_image = cv2.threshold(image, 127, 255, cv2.THRESH_BINARY)

# Encontrar los contornos
contours, hierarchy = cv2.findContours(thresholded_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

'''
cv2.findContours()`**: Encuentra los contornos en la imagen binarizada.
- cv2.RETR_EXTERNAL` para detectar solo los contornos exteriores de los objetos
- cv2.CHAIN_APPROX_SIMPLE para simplificar los contornos.
'''

# Dibujar los contornos sobre la imagen original
image_with_contours = cv2.cvtColor(thresholded_image, cv2.COLOR_GRAY2BGR)  # Convertir a color
cv2.drawContours(image_with_contours, contours, -1, (0, 255, 0), 3)

# Mostrar la imagen con contornos
# cv2.imshow('Segmentación por Contornos', image_with_contours)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

plt.title('Segmentación por Contornos')
plt.imshow(image_with_contours, cmap='gray')
plt.axis('off')  # Ocultar los ejes
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Cargar imagen en color
image = cv2.imread('/content/imagen_color.png')

# Convertir la imagen a una matriz de datos 2D (un píxel por fila)
#Es una tupla que define la nueva forma o dimensiones del array.
#El número total de elementos en la nueva forma debe ser igual al número total de elementos en el array original.
#Si no se sabe la longitud de una de las dimensiones, puedes usar -1
#NumPy la calcule automáticamente en función de las otras dimensiones.
Z = image.reshape((-1, 3))

# Convertir a flotante
Z = np.float32(Z)

# Definir criterios y aplicar kmeans
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 100, 0.2)
#Definir los criterios de terminación: maximo de 100 iteraciones o si el cambio es menor que 0.2

k = 2  # Número de clusters
ret, label, center = cv2.kmeans(Z, k, None, criteria, 10, cv2.KMEANS_RANDOM_CENTERS)

# Convertir de nuevo los centros a 8 bits
center = np.uint8(center)
# Convertir los centros de los clusters a 8 bits (ya que los valores estaban en float32)

# Etiquetas de los clusters
res = center[label.flatten()]
# Reemplazar los valores de cada píxel con el centro de su respectivo cluster

# Remodelar la imagen segmentada para que tenga la misma forma que la original
result_image = res.reshape((image.shape))

# Mostrar la imagen segmentada
# cv2.imshow('Segmentación con K-means', result_image)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

plt.title('Segmentación con K-means')
plt.imshow(result_image)
plt.axis('off')  # Ocultar los ejes
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Cargar imagen
image = cv2.imread('/content/imagen_color.png')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Aplicar umbralización

# Hallar los contornos
dist_transform = cv2.distanceTransform(thresholded_image, cv2.DIST_L2, 5)
ret, markers = cv2.threshold(dist_transform, 0.7*dist_transform.max(), 255, 0)

# Aplicar watershed
markers = np.int32(markers)
cv2.watershed(image, markers)

# Marcamos los bordes en color rojo
image[markers == -1] = [0, 0, 255]

# Mostrar la imagen segmentada
# cv2.imshow('Segmentación con Watershed', image)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

plt.title('Segmentación con Watershed')
plt.imshow(image, cmap='gray')
plt.axis('off')  # Ocultar los ejes
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Cargar imagen en escala de grises
image = cv2.imread('/content/imagen_color.png', 0)

# Umbral para definir la región de inicio
_, thresholded_image = cv2.threshold(image, 127, 255, cv2.THRESH_BINARY)

# Región inicial
seed_point = (50, 50)  # Semilla inicial

# Aplicar el crecimiento de región (simplificado)
# (Implementación real sería más compleja)

# cv2.imshow('Segmentación Crecimiento de Regiones', thresholded_image)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

plt.title('Segmentación Crecimiento de Regiones')
plt.imshow(thresholded_image, cmap='gray')
plt.axis('off')  # Ocultar los ejes
plt.show()

# %%
#### Ejemplo de Crecimiento de Regiones usando Seed Points:

import cv2
import numpy as np


# Crear una máscara de la imagen
mask = np.zeros_like(image)

# Definir los seed points (ejemplo: [100, 100] y [200, 200])
seed_points = [(100, 100), (200, 200)]

# Establecer un umbral para el crecimiento de la región
threshold = 20

# Función de crecimiento de regiones
def region_growing(seed_points, image, threshold=20):
    # Obtener la forma de la imagen
    rows, cols = image.shape
    mask = np.zeros_like(image)  # Crear la máscara

    for seed in seed_points:
        # Establecer el píxel semilla en la máscara
        mask[seed] = 255
        region_mean = image[seed]  # Promedio de la región inicial

        # Expansión de la región
        for i in range(rows):
            for j in range(cols):
                if mask[i, j] == 0:  # Si el píxel no está marcado
                    if abs(int(image[i, j]) - int(region_mean)) < threshold:
                        mask[i, j] = 255  # Marcar el píxel como parte de la región

    return mask

# Aplicar la función de crecimiento de regiones
result_mask = region_growing(seed_points, gray, threshold)

# Mostrar la imagen original y la máscara de la región segmentada
'''
cv2.imshow('Imagen Original', image)
cv2.imshow('Máscara Segmentada', result_mask)
cv2.waitKey(0)
cv2.destroyAllWindows()'''

plt.title('Imagen Original')
plt.imshow(image)
plt.axis('off')  # Ocultar los ejes
plt.show()


plt.title('Máscara Segmentada')
plt.imshow(result_mask)
plt.axis('off')  # Ocultar los ejes
plt.show()

# %%
import cv2
import numpy as np

# Cargar la imagen
img = cv2.imread('/content/imagen_color.png')

# Convertir la imagen a escala de grises
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Aplicar un umbral binario
_, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

# Encontrar los contornos
contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Crear una imagen vacía para los marcadores con 1 canal
markers = np.zeros_like(gray, dtype=np.int32) # Changed to gray and dtype to int32

# Definir los seed points (por ejemplo, marcar manualmente las regiones de interés)
for i in range(len(contours)):
    cv2.drawContours(markers, contours, i, (i + 1), -1)

# Marcar el fondo como -1
markers[thresh == 0] = -1

# Aplicar Watershed
cv2.watershed(img, markers)

# Las fronteras de los objetos serán marcadas con -1
img[markers == -1] = [0, 0, 255]  # Rojo para las fronteras

# Mostrar la imagen resultante

plt.title('Segmentación Watershed')
plt.imshow(img)
plt.axis('off')  # Ocultar los ejes
plt.show()

# %%
# Cargar imagen en color
import matplotlib.pyplot as plt
import cv2
import numpy as np
image = cv2.imread('/content/imagen_color.png')

# Convertir a espacio de color HSV
hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

# Definir rango de color en el espacio HSV
lower_bound = np.array([30, 50, 50])  # Rango inferior (ej. verde)
upper_bound = np.array([80, 255, 255])  # Rango superior

# Crear máscara para segmentar el color verde
mask = cv2.inRange(hsv_image, lower_bound, upper_bound)

# Aplicar máscara sobre la imagen original
segmented_image = cv2.bitwise_and(image, image, mask=mask)

# Mostrar resultados
# cv2.imshow('Segmentación de Color', segmented_image)
# cv2.waitKey(0)
# cv2.destroyAllWindows()


plt.title('Segmentación de Color')
plt.imshow(segmented_image)
plt.axis('off')  # Ocultar los ejes
plt.show()

# %%
### **Ejemplo 2: Detectar el color rojo en una imagen** (en el espacio de color HSV):

import cv2
import numpy as np

# Cargar la imagen
img = cv2.imread('/content/imagen_color.png')

# Convertir la imagen de BGR a HSV
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

# Definir el rango de color rojo en HSV (rojo tiene dos rangos en HSV)
lower_red1 = np.array([0, 120, 70])   # Rango inferior del primer rango de rojo
upper_red1 = np.array([10, 255, 255]) # Rango superior del primer rango de rojo

lower_red2 = np.array([170, 120, 70]) # Rango inferior del segundo rango de rojo
upper_red2 = np.array([180, 255, 255]) # Rango superior del segundo rango de rojo

# Crear dos máscaras para los dos rangos del color rojo
mask1 = cv2.inRange(hsv, lower_red1, upper_red1)
mask2 = cv2.inRange(hsv, lower_red2, upper_red2)

# Unir las dos máscaras
mask = cv2.bitwise_or(mask1, mask2)

# Aplicar la máscara a la imagen original
result = cv2.bitwise_and(img, img, mask=mask)

plt.title('Segmentación de Color')
plt.imshow(mask)
plt.axis('off')  # Ocultar los ejes
plt.show()

# %%
#### Ejemplo: Aplicar una máscara en una imagen en escala de grises

import cv2
import numpy as np

# Cargar una imagen en escala de grises
img = cv2.imread('/content/imagen_color.png', cv2.IMREAD_GRAYSCALE)

# Crear una máscara binaria (por ejemplo, seleccionar píxeles que sean mayores que 100)
_, mask = cv2.threshold(img, 100, 255, cv2.THRESH_BINARY)

# Aplicar la máscara a la imagen original usando bitwise_and
result = cv2.bitwise_and(img, img, mask=mask)

# Mostrar la imagen original, la máscara y el resultado
plt.title('Segmentación de Color')
plt.imshow(mask, cmap='gray')
plt.axis('off')  # Ocultar los ejes
plt.show()
