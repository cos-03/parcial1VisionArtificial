# %%
pip install opencv-python scikit-image
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Cargar la imagen
image = cv2.imread('image.jpg', cv2.IMREAD_GRAYSCALE)



imagen_suavizada = cv2.GaussianBlur(image, (5, 5), 0)

# Umbralizar la imagen para obtener una imagen binaria (en caso de que sea una imagen de fondo blanco y negro)
_, binary_image = cv2.threshold(imagen_suavizada, 107, 255, cv2.THRESH_BINARY)
imag = cv2.Canny(binary_image, 100, 200)

# Calcular los momentos de la imagen binaria
moments = cv2.moments(imag)

# Calcular los Momentos de Hu
hu_moments_1 = cv2.HuMoments(moments)
print(hu_moments_1)

# Mostrar los Momentos de Hu
print("Momentos de Hu:")
for i in range(7):
    print(f'Momento {i+1}: {hu_moments_1[i][0]}')

# Puedes visualizar la imagen original
# cv2.imshow("Imagen", image)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

plt.title('Imagen')
plt.imshow(imag, cmap='gray')
plt.axis('off')  # Ocultar los ejes
plt.show()

import cv2
import numpy as np
import matplotlib.pyplot as plt

# Cargar la imagen
image = cv2.imread('image.jpg', cv2.IMREAD_GRAYSCALE)

# Umbralizar la imagen para obtener una imagen binaria (en caso de que sea una imagen de fondo blanco y negro)
_, binary_image = cv2.threshold(image, 127, 255, cv2.THRESH_BINARY)

# Calcular los momentos de la imagen binaria
moments = cv2.moments(binary_image)

# Calcular los Momentos de Hu
hu_moments_2 = cv2.HuMoments(moments)
print(hu_moments_2)

# Mostrar los Momentos de Hu
print("Momentos de Hu:")
for i in range(7):
    print(f'Momento {i+1}: {hu_moments_2[i][0]}')

# Puedes visualizar la imagen original
# cv2.imshow("Imagen", image)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

plt.title('Imagen')
plt.imshow(image, cmap='gray')
plt.axis('off')  # Ocultar los ejes
plt.show()

distance_1 = np.linalg.norm(hu_moments_1 - hu_moments_2)

print(f"Distancia Euclidiana entre los momentos de Hu: {distance_1}")


import cv2
import numpy as np
import matplotlib.pyplot as plt

# Cargar la imagen
image = cv2.imread('image.jpg', cv2.IMREAD_GRAYSCALE)

# Umbralizar la imagen para obtener una imagen binaria (en caso de que sea una imagen de fondo blanco y negro)
_, binary_image = cv2.threshold(image, 127, 255, cv2.THRESH_BINARY)

# Calcular los momentos de la imagen binaria
moments = cv2.moments(binary_image)

# Calcular los Momentos de Hu
hu_moments_3 = cv2.HuMoments(moments)
print(hu_moments_3)

# Mostrar los Momentos de Hu
print("Momentos de Hu:")
for i in range(7):
    print(f'Momento {i+1}: {hu_moments_3[i][0]}')

# Puedes visualizar la imagen original
# cv2.imshow("Imagen", image)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

plt.title('Imagen')
plt.imshow(image, cmap='gray')
plt.axis('off')  # Ocultar los ejes
plt.show()

print(hu_moments_1)
print()
print(hu_moments_2)
print()
print(hu_moments_3)


distance_2 = np.linalg.norm(hu_moments_2 - hu_moments_3)

print(f"Distancia Euclidiana entre los momentos de Hu: {distance_2}")

print(distance_1)
print(distance_2)
# Out:
# [[ 4.13739092e-02]
#  [ 7.06727101e-04]
#  [ 1.28270428e-06]
#  [ 9.88153389e-07]
#  [-1.10548663e-12]
#  [-2.49228384e-08]
#  [ 1.24717345e-13]]
# Momentos de Hu:
# Momento 1: 0.041373909202632085
# Momento 2: 0.0007067271013331247
# Momento 3: 1.282704281933052e-06
# Momento 4: 9.881533893917611e-07
# Momento 5: -1.1054866310045275e-12
# Momento 6: -2.4922838448862732e-08
# Momento 7: 1.2471734483204098e-13

# %%
# Out:
# [[ 2.36239192e-03]
#  [ 9.19728579e-07]
#  [ 4.21456307e-09]
#  [ 5.91497034e-10]
#  [-5.13042409e-19]
#  [-5.52839732e-13]
#  [-7.80369024e-19]]
# Momentos de Hu:
# Momento 1: 0.002362391916390736
# Momento 2: 9.197285792842046e-07
# Momento 3: 4.214563065922003e-09
# Momento 4: 5.914970335054739e-10
# Momento 5: -5.130424085654027e-19
# Momento 6: -5.528397323114669e-13
# Momento 7: -7.8036902374504135e-19

# %%
# Out:
# Distancia Euclidiana entre los momentos de Hu: 0.03901790163031037

# %%
# Out:
# [[ 2.36239192e-03]
#  [ 9.19728579e-07]
#  [ 4.21456307e-09]
#  [ 5.91497034e-10]
#  [-5.13042409e-19]
#  [-5.52839732e-13]
#  [-7.80369024e-19]]
# Momentos de Hu:
# Momento 1: 0.002362391916390736
# Momento 2: 9.197285792842046e-07
# Momento 3: 4.214563065922003e-09
# Momento 4: 5.914970335054739e-10
# Momento 5: -5.130424085654027e-19
# Momento 6: -5.528397323114669e-13
# Momento 7: -7.8036902374504135e-19

# %%
# Out:
# [[ 4.13739092e-02]
#  [ 7.06727101e-04]
#  [ 1.28270428e-06]
#  [ 9.88153389e-07]
#  [-1.10548663e-12]
#  [-2.49228384e-08]
#  [ 1.24717345e-13]]
#
# [[ 2.36239192e-03]
#  [ 9.19728579e-07]
#  [ 4.21456307e-09]
#  [ 5.91497034e-10]
#  [-5.13042409e-19]
#  [-5.52839732e-13]
#  [-7.80369024e-19]]
#
# [[ 2.36239192e-03]
#  [ 9.19728579e-07]
#  [ 4.21456307e-09]
#  [ 5.91497034e-10]
#  [-5.13042409e-19]
#  [-5.52839732e-13]
#  [-7.80369024e-19]]

# %%
# Out:
# Distancia Euclidiana entre los momentos de Hu: 0.0

# %%
# Out:
# 0.03901790163031037
# 0.0
