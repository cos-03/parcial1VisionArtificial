# %%
# %pip install opencv-python numpy matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python in c:\users\felipe\appdata\roaming\python\python312\site-packages (4.12.0.88)
# Requirement already satisfied: numpy in c:\users\felipe\appdata\roaming\python\python312\site-packages (2.2.6)
# Requirement already satisfied: matplotlib in c:\users\felipe\appdata\roaming\python\python312\site-packages (3.10.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\felipe\appdata\roaming\python\python312\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\felipe\appdata\roaming\python\python312\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\felipe\appdata\roaming\python\python312\site-packages (from matplotlib) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\felipe\appdata\roaming\python\python312\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\felipe\appdata\roaming\python\python312\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\felipe\appdata\roaming\python\python312\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\felipe\appdata\roaming\python\python312\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\felipe\appdata\roaming\python\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\felipe\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# 1. Cambiar de RGB a Escala de Grises
img = cv2.imread('/content/busy-students-one-table.jpg')
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray_img, cmap='gray')
plt.axis('off')
plt.show()

# 2. Convertir a Blanco y Negro (Binaria)
_, binary_img = cv2.threshold(gray_img, 128, 255, cv2.THRESH_BINARY)
fig, axes = plt.subplots(2, 1, figsize=(15, 5))
axes[0].imshow(gray_img, cmap='gray')
axes[0].set_title("Escala de Grises")
axes[0].axis('off')
axes[1].imshow(binary_img, cmap='gray')
axes[1].set_title("Blanco y Negro")
axes[1].axis('off')
plt.show()

# 3. Cambiar de Tamaño (Reducción o Amplificación)
resized_img = cv2.resize(img, (400, 400))
plt.imshow(resized_img)
plt.axis('off')
plt.show()

# 4. Operaciones Geométricas: Rotación
(h, w) = img.shape[:2]
center = (w // 2, h // 2)
M = cv2.getRotationMatrix2D(center, 45, 1.0)
rotated_img = cv2.warpAffine(img, M, (w, h))
plt.imshow(rotated_img)
plt.axis('off')
plt.show()

# 5. Operaciones Aritméticas: Suma, Resta, Multiplicación y División
img1 = cv2.imread('/content/busy-students-one-table.jpg')
img2 = cv2.imread('/content/room-interior-design.jpg')
sum_img = cv2.add(img1, img2)
diff_img = cv2.subtract(img1, img2)
mult_img = cv2.multiply(img1, img2)
div_img = cv2.divide(img1, img2)
fig, axes = plt.subplots(2, 2, figsize=(15, 5))
axes[0][0].imshow(sum_img, cmap='gray')
axes[0][0].set_title("Suma")
axes[0][0].axis('off')
axes[0][1].imshow(diff_img, cmap='gray')
axes[0][1].set_title("Resta")
axes[0][1].axis('off')
axes[1][0].imshow(mult_img, cmap='gray')
axes[1][0].set_title("Multiplicación")
axes[1][0].axis('off')
axes[1][1].imshow(div_img, cmap='gray')
axes[1][1].set_title("División")
axes[1][1].axis('off')
plt.show()

# 6. Operaciones Lógicas: AND, OR, NOT
img1 = cv2.imread('/content/busy-students-one-table.jpg', cv2.IMREAD_GRAYSCALE)
img2 = cv2.imread('/content/room-interior-design.jpg', cv2.IMREAD_GRAYSCALE)
_, img1_bin = cv2.threshold(img1, 128, 255, cv2.THRESH_BINARY)
_, img2_bin = cv2.threshold(img2, 128, 255, cv2.THRESH_BINARY)
and_img = cv2.bitwise_and(img1_bin, img2_bin)
or_img = cv2.bitwise_or(img1_bin, img2_bin)
not_img1 = cv2.bitwise_not(img1_bin)
not_img2 = cv2.bitwise_not(img2_bin)
fig, axes = plt.subplots(2, 2, figsize=(15, 5))
axes[0][0].imshow(and_img, cmap='gray')
axes[0][0].set_title("AND")
axes[0][0].axis('off')
axes[0][1].imshow(or_img, cmap='gray')
axes[0][1].set_title("OR")
axes[0][1].axis('off')
axes[1][0].imshow(not_img1, cmap='gray')
axes[1][0].set_title("NOT IMAGEN UNO")
axes[1][0].axis('off')
axes[1][1].imshow(not_img2, cmap='gray')
axes[1][1].set_title("NOT IMAGEN DOS")
axes[1][1].axis('off')
plt.show()

# 7. Interpolación (Reducción y Amplificación)
resized_bilinear = cv2.resize(img, (400, 400), interpolation=cv2.INTER_LINEAR)
resized_nearest = cv2.resize(img, (400, 400), interpolation=cv2.INTER_NEAREST)
fig, axes = plt.subplots(2, 1, figsize=(15, 5))
axes[0].imshow(resized_bilinear, cmap='gray')
axes[0].set_title("Interpolación Bilineal")
axes[0].axis('off')
axes[1].imshow(resized_nearest, cmap='gray')
axes[1].set_title("Interpolación Vecino más cercano")
axes[1].axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[4], line 7
#       5 # 1. Cambiar de RGB a Escala de Grises
#       6 img = cv2.imread('/content/busy-students-one-table.jpg')
# ----> 7 gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#       8 plt.imshow(gray_img, cmap='gray')
#       9 plt.axis('off')
#
# error: OpenCV(4.12.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
